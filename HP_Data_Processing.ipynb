# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import csv
import xml.etree.ElementTree as ET
import glob

# %% [markdown]
# # Ohio1TD Dataset

# %%
# Define the folder containing the XML files
input_folder = 'OhioT1D'
output_folder = 'Processed_Data/T1D_Data'
os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

# Loop through each XML file in the folder
for filename in os.listdir(input_folder):
    if filename.endswith('.xml'):  # Process only XML files
        input_file_path = os.path.join(input_folder, filename)
        output_file_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_processed.csv")

        # Load and parse the XML file
        tree = ET.parse(input_file_path)
        root = tree.getroot()

        # Extract glucose level data and format it
        glucose_data = []
        for event in root.find('glucose_level').findall('event'):
            timestamp = event.get('ts')  # Get the timestamp

            # Convert glucose value and round to 2 decimal places
            value = round(float(event.get('value')) / 18, 2)

            time_only = timestamp.split(' ')[1]  # Extract time (HH:MM:SS)
            glucose_data.append((time_only, value))

        # Write to a CSV file
        with open(output_file_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Time', 'Glucose'])  # Write header
            writer.writerows(glucose_data)  # Write data rows

        # Create extra time and classification attributes
        df = pd.read_csv(output_file_path)
        df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
        df['Hour'] = df['Time'].dt.hour
        df['Minute'] = df['Time'].dt.minute
        df["Hour_sin"] = np.sin(2 * np.pi * df["Hour"] / 24)
        df["Hour_cos"] = np.cos(2 * np.pi * df["Hour"] / 24)
        df["Minute_sin"] = np.sin(2 * np.pi * df["Minute"] / 60)
        df["Minute_cos"] = np.cos(2 * np.pi * df["Minute"] / 60)

        # Drop null values from 'Glucose' column
        df['Glucose'].replace('', pd.NA)
        df = df.dropna(subset=['Glucose'])

        # Define glucose level thresholds
        bins = [-float('inf'), 2.5, 5, 8, 10, float('inf')]
        labels = ['Very Low', 'Low', 'Normal', 'High', 'Very High']
        df['Glucose_Level_Range'] = pd.cut(df['Glucose'], bins=bins, labels=labels)

        # Create attributes and values for future time-prediction modelling
        # Rolling window features
        df["Glucose_roll_mean"] = df["Glucose"].rolling(window=5, min_periods=1).mean()

        # Previous glucose values
        df["Glucose_lag1"] = df["Glucose"].shift(1)
        df["Glucose_lag2"] = df["Glucose"].shift(2)
        df["Glucose_lag3"] = df["Glucose"].shift(3)
        df["Glucose_lag4"] = df["Glucose"].shift(4)

        # Drop NaN values from feature generation
        df.dropna(inplace=True)

        # Future glucose values
        df["Glucose_15min"] = df["Glucose"].shift(-3)  # 15 minutes ahead
        df["Glucose_30min"] = df["Glucose"].shift(-6)  # 30 minutes ahead
        df["Glucose_45min"] = df["Glucose"].shift(-9)  # 45 minutes ahead
        df["Glucose_60min"] = df["Glucose"].shift(-12) # 60 minutes ahead

        # Drop NaN values after shifting
        df.dropna(inplace=True)

        # Shape and missing values
        print(df.shape)
        print("Missing values:")
        print(df.isna().sum())

        df.to_csv(output_file_path, index=False)
        print(f"\nProcessed {filename} and saved to {output_file_path}")
# Out:
# (10780, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 559-ws-training.xml and saved to Processed_Data/T1D_Data/559-ws-training_processed.csv
# (2498, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 559-ws-testing.xml and saved to Processed_Data/T1D_Data/559-ws-testing_processed.csv
# (10831, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 591-ws-training.xml and saved to Processed_Data/T1D_Data/591-ws-training_processed.csv
# (11850, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 575-ws-training.xml and saved to Processed_Data/T1D_Data/575-ws-training_processed.csv
# (2775, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 588-ws-testing.xml and saved to Processed_Data/T1D_Data/588-ws-testing_processed.csv
# (12108, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 563-ws-training.xml and saved to Processed_Data/T1D_Data/563-ws-training_processed.csv
# (12624, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 588-ws-training.xml and saved to Processed_Data/T1D_Data/588-ws-training_processed.csv
# (10966, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 570-ws-training.xml and saved to Processed_Data/T1D_Data/570-ws-training_processed.csv
# (2574, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 575-ws-testing.xml and saved to Processed_Data/T1D_Data/575-ws-testing_processed.csv
# (2729, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 570-ws-testing.xml and saved to Processed_Data/T1D_Data/570-ws-testing_processed.csv
# (2554, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 563-ws-testing.xml and saved to Processed_Data/T1D_Data/563-ws-testing_processed.csv
# (2744, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 591-ws-testing.xml and saved to Processed_Data/T1D_Data/591-ws-testing_processed.csv

# %% [markdown]
# # ShanghaiT1DM Dataset

# %%
# Define the folder containing the Excel files
input_folder = 'Shanghai_T1DM'
output_folder = 'Processed_Data/T1D_Data'
os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

# Loop through each Excel file in the folder
for filename in os.listdir(input_folder):
    if filename.endswith(('.xlsx', '.xls')):  # Process only Excel files
        input_file_path = os.path.join(input_folder, filename)
        output_file_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_processed.csv")

        # Load the Excel file
        try:
            df = pd.read_excel(input_file_path)

            # Extract time from the timestamp and rename columns
            df['Time'] = pd.to_datetime(df['Date']).dt.time  # Extract time
            df['Glucose'] = (df['CGM (mg / dl)'] / 18).round(2)  # Scale and round Glucose values

            # Drop null values from 'Glucose' column
            df['Glucose'].replace('', pd.NA)
            df = df.dropna(subset=['Glucose'])

            # Create extra time and classification attributes
            df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
            df['Hour'] = df['Time'].dt.hour
            df['Minute'] = df['Time'].dt.minute
            df["Hour_sin"] = np.sin(2 * np.pi * df["Hour"] / 24)
            df["Hour_cos"] = np.cos(2 * np.pi * df["Hour"] / 24)
            df["Minute_sin"] = np.sin(2 * np.pi * df["Minute"] / 60)
            df["Minute_cos"] = np.cos(2 * np.pi * df["Minute"] / 60)

            # Define glucose level thresholds
            bins = [-float('inf'), 2.5, 5, 8, 10, float('inf')]
            labels = ['Very Low', 'Low', 'Normal', 'High', 'Very High']
            df['Glucose_Level_Range'] = pd.cut(df['Glucose'], bins=bins, labels=labels)

            # Create attributes and values for future time-prediction modelling
            # Rolling window features
            df["Glucose_roll_mean"] = df["Glucose"].rolling(window=5, min_periods=1).mean()

            # Previous glucose values
            df["Glucose_lag1"] = df["Glucose"].shift(1)
            df["Glucose_lag2"] = df["Glucose"].shift(2)
            df["Glucose_lag3"] = df["Glucose"].shift(3)
            df["Glucose_lag4"] = df["Glucose"].shift(4)

            # Future glucose values
            df["Glucose_15min"] = df["Glucose"].shift(-1)  # 15 minutes ahead
            df["Glucose_30min"] = df["Glucose"].shift(-2)  # 30 minutes ahead
            df["Glucose_45min"] = df["Glucose"].shift(-3)  # 45 minutes ahead
            df["Glucose_60min"] = df["Glucose"].shift(-4) # 60 minutes ahead

            # Create a new DataFrame with only the desired columns
            new_df = df[['Time', 'Glucose', 'Hour', 'Minute', 'Glucose_Level_Range', 'Hour_sin', 'Hour_cos',
                         'Minute_sin', 'Minute_cos','Glucose_roll_mean','Glucose_lag1', 'Glucose_lag2', 'Glucose_lag3', 'Glucose_lag4',
                         'Glucose_15min', 'Glucose_30min', 'Glucose_45min', 'Glucose_60min']]

            # Write to a CSV file
            new_df.to_csv(output_file_path, index=False)
            created_df = pd.read_csv(output_file_path)

            #Drop null values
            created_df.dropna(inplace=True)
            created_df.to_csv(output_file_path, index=False)

            # Shape and missing values
            print(created_df.shape)
            print("Missing values:")
            print(created_df.isna().sum())

            print(f"\nProcessed {filename} and saved to {output_file_path}")
        except Exception as e:
            print(f"Failed to process {filename}: {e}")
# Out:
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1012_0_20210923.xls and saved to Processed_Data/T1D_Data/1012_0_20210923_processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1006_1_20210209.xlsx and saved to Processed_Data/T1D_Data/1006_1_20210209_processed.csv
# (673, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1009_0_20210803.xls and saved to Processed_Data/T1D_Data/1009_0_20210803_processed.csv
# (909, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1004_0_20210425.xls and saved to Processed_Data/T1D_Data/1004_0_20210425_processed.csv
# (349, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1002_2_20210909.xls and saved to Processed_Data/T1D_Data/1002_2_20210909_processed.csv
# (1248, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1005_0_20210522.xls and saved to Processed_Data/T1D_Data/1005_0_20210522_processed.csv
# (940, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1002_0_20210504.xls and saved to Processed_Data/T1D_Data/1002_0_20210504_processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1003_0_20210831.xls and saved to Processed_Data/T1D_Data/1003_0_20210831_processed.csv
# (758, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1008_0_20210713.xls and saved to Processed_Data/T1D_Data/1008_0_20210713_processed.csv
# (1228, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1006_0_20210114.xlsx and saved to Processed_Data/T1D_Data/1006_0_20210114_processed.csv
# (910, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1010_0_20210915.xls and saved to Processed_Data/T1D_Data/1010_0_20210915_processed.csv
# (925, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1002_1_20210521.xls and saved to Processed_Data/T1D_Data/1002_1_20210521_processed.csv
# (1329, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1007_0_20210726.xls and saved to Processed_Data/T1D_Data/1007_0_20210726_processed.csv
# (1127, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1006_2_20210303.xlsx and saved to Processed_Data/T1D_Data/1006_2_20210303_processed.csv
# (528, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1011_0_20210622.xls and saved to Processed_Data/T1D_Data/1011_0_20210622_processed.csv
# (650, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 1001_0_20210730.xlsx and saved to Processed_Data/T1D_Data/1001_0_20210730_processed.csv

# %% [markdown]
# # ShanghaiT2DM Dataset

# %%
# Define the folder containing the Excel files
input_folder = 'Shanghai_T2DM'
output_folder = 'Processed_Data/T2D_Data'
os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

# Loop through each Excel file in the folder
for filename in os.listdir(input_folder):
    if filename.endswith(('.xlsx', '.xls')):  # Process only Excel files
        input_file_path = os.path.join(input_folder, filename)
        output_file_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_processed.csv")

        # Load the Excel file
        try:
            df = pd.read_excel(input_file_path)

            # Extract time from the timestamp and rename columns
            df['Date'] = df['Date'].astype(str)
            df['Time'] = df['Date'].str.split('.').str[0]  # Remove fractional seconds
            df['Time'] = pd.to_datetime(df['Time']).dt.time  # Extract time

            # List of column names that contain glucose values
            glucose_columns = ['CGM (mg / dl)', 'CGM ']

            # Loop through the list of possible column names
            for col in glucose_columns:
              if col in df.columns:  # Check if column exists
                df['Glucose'] = (df[col] / 18).round(2)  # Convert and round
                break  # Stop once we find and process the correct column

            # Drop null values from 'Glucose' column
            df['Glucose'].replace('', pd.NA)
            df = df.dropna(subset=['Glucose'])

            # Create extra time and classification attributes
            df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
            df['Hour'] = df['Time'].dt.hour
            df['Minute'] = df['Time'].dt.minute
            df["Hour_sin"] = np.sin(2 * np.pi * df["Hour"] / 24)
            df["Hour_cos"] = np.cos(2 * np.pi * df["Hour"] / 24)
            df["Minute_sin"] = np.sin(2 * np.pi * df["Minute"] / 60)
            df["Minute_cos"] = np.cos(2 * np.pi * df["Minute"] / 60)

            # Define glucose level thresholds
            bins = [-float('inf'), 2.5, 5, 8, 10, float('inf')]
            labels = ['Very Low', 'Low', 'Normal', 'High', 'Very High']
            df['Glucose_Level_Range'] = pd.cut(df['Glucose'], bins=bins, labels=labels)

            #Create attributes and values for future time-prediction modelling
            # Rolling window features
            df["Glucose_roll_mean"] = df["Glucose"].rolling(window=5, min_periods=1).mean()

            # Previous glucose values
            df["Glucose_lag1"] = df["Glucose"].shift(1)
            df["Glucose_lag2"] = df["Glucose"].shift(2)
            df["Glucose_lag3"] = df["Glucose"].shift(3)
            df["Glucose_lag4"] = df["Glucose"].shift(4)


            # Future glucose values
            df["Glucose_15min"] = df["Glucose"].shift(-1)  # 15 minutes ahead
            df["Glucose_30min"] = df["Glucose"].shift(-2)  # 30 minutes ahead
            df["Glucose_45min"] = df["Glucose"].shift(-3)  # 45 minutes ahead
            df["Glucose_60min"] = df["Glucose"].shift(-4) # 60 minutes ahead

            # Create a new DataFrame with only the desired columns
            new_df = df[['Time', 'Glucose', 'Hour', 'Minute', 'Glucose_Level_Range', 'Hour_sin', 'Hour_cos',
                         'Minute_sin', 'Minute_cos','Glucose_roll_mean','Glucose_lag1', 'Glucose_lag2', 'Glucose_lag3', 'Glucose_lag4',
                         'Glucose_15min', 'Glucose_30min', 'Glucose_45min', 'Glucose_60min']]

            # Write to a CSV file
            new_df.to_csv(output_file_path, index=False)
            created_df = pd.read_csv(output_file_path)

            #Drop null values
            created_df.dropna(inplace=True)
            created_df.to_csv(output_file_path, index=False)

            # Shape and missing values
            print(created_df.shape)
            print("Missing values:")
            print(created_df.isna().sum())

            print(f"\nProcessed {filename} and saved to {output_file_path}")
        except Exception as e:
            print(f"Failed to process {filename}: {e}")
# Out:
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2001_1_20201117.xlsx and saved to Processed_Data/T2D_Data/2001_1_20201117_processed.csv
# (1137, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2074_0_20210707.xls and saved to Processed_Data/T2D_Data/2074_0_20210707_processed.csv
# (517, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2054_0_20210524.xls and saved to Processed_Data/T2D_Data/2054_0_20210524_processed.csv
# (1214, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2053_0_20210518.xls and saved to Processed_Data/T2D_Data/2053_0_20210518_processed.csv
# (486, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2009_0_20211103.xlsx and saved to Processed_Data/T2D_Data/2009_0_20211103_processed.csv
# (531, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2020_0_20210423.xls and saved to Processed_Data/T2D_Data/2020_0_20210423_processed.csv
# (938, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2030_0_20210531.xls and saved to Processed_Data/T2D_Data/2030_0_20210531_processed.csv
# (661, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2003_0_20210615.xlsx and saved to Processed_Data/T2D_Data/2003_0_20210615_processed.csv
# (531, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2010_0_20220111.xlsx and saved to Processed_Data/T2D_Data/2010_0_20220111_processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2055_1_20201207.xls and saved to Processed_Data/T2D_Data/2055_1_20201207_processed.csv
# (379, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2034_0_20210624.xls and saved to Processed_Data/T2D_Data/2034_0_20210624_processed.csv
# (1325, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2092_0_20201109.xls and saved to Processed_Data/T2D_Data/2092_0_20201109_processed.csv
# (1197, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2062_0_20210601.xls and saved to Processed_Data/T2D_Data/2062_0_20210601_processed.csv
# (1324, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2088_0_20201123.xls and saved to Processed_Data/T2D_Data/2088_0_20201123_processed.csv
# (342, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2013_0_20220123.xlsx and saved to Processed_Data/T2D_Data/2013_0_20220123_processed.csv
# (1037, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2055_0_20210524.xls and saved to Processed_Data/T2D_Data/2055_0_20210524_processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2016_0_20201224.xls and saved to Processed_Data/T2D_Data/2016_0_20201224_processed.csv
# (1329, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2017_0_20210102.xlsx and saved to Processed_Data/T2D_Data/2017_0_20210102_processed.csv
# (1236, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 
processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2014_1_20210317.xlsx and saved to Processed_Data/T2D_Data/2014_1_20210317_processed.csv
# (1212, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2064_0_20210608.xls and saved to Processed_Data/T2D_Data/2064_0_20210608_processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2078_0_20210803.xls and saved to Processed_Data/T2D_Data/2078_0_20210803_processed.csv
# (1016, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2040_0_20210729.xls and saved to Processed_Data/T2D_Data/2040_0_20210729_processed.csv
# (1039, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2082_0_20210907.xls and saved to Processed_Data/T2D_Data/2082_0_20210907_processed.csv
# (525, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2008_0_20220118.xlsx and saved to Processed_Data/T2D_Data/2008_0_20220118_processed.csv
# (1215, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2063_0_20210608.xls and saved to Processed_Data/T2D_Data/2063_0_20210608_processed.csv
# (970, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2074_1_20210720.xls and saved to Processed_Data/T2D_Data/2074_1_20210720_processed.csv
# (1330, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2037_0_20201221.xls and saved to Processed_Data/T2D_Data/2037_0_20201221_processed.csv
# (454, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2011_0_20220123.xlsx and saved to Processed_Data/T2D_Data/2011_0_20220123_processed.csv
# (718, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2033_0_20210615.xls and saved to Processed_Data/T2D_Data/2033_0_20210615_processed.csv
# (1321, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2080_0_20210816.xls and saved to Processed_Data/T2D_Data/2080_0_20210816_processed.csv
# (1321, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2095_0_20201116.xls and saved to Processed_Data/T2D_Data/2095_0_20201116_processed.csv
# (655, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2084_0_20211013.xls and saved to Processed_Data/T2D_Data/2084_0_20211013_processed.csv
# (1213, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2081_0_20210817.xls and saved to Processed_Data/T2D_Data/2081_0_20210817_processed.csv
# (1325, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2078_1_20210817.xls and saved to Processed_Data/T2D_Data/2078_1_20210817_processed.csv
# (1015, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2077_0_20210803.xls and saved to Processed_Data/T2D_Data/2077_0_20210803_processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2085_0_20200907.xls and saved to Processed_Data/T2D_Data/2085_0_20200907_processed.csv
# (753, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2025_0_20210506.xls and saved to Processed_Data/T2D_Data/2025_0_20210506_processed.csv
# (1323, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2083_0_20201214.xls and saved to Processed_Data/T2D_Data/2083_0_20201214_processed.csv
# (280, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2012_0_20220126.xlsx and saved to Processed_Data/T2D_Data/2012_0_20220126_processed.csv
# (1241, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2052_0_20210511.xls and saved to Processed_Data/T2D_Data/2052_0_20210511_processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2091_0_20201029.xls and saved to Processed_Data/T2D_Data/2091_0_20201029_processed.csv
# (1331, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2000_0_20201230.xlsx and saved to Processed_Data/T2D_Data/2000_0_20201230_processed.csv
# (1187, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2001_0_20201102.xlsx and saved to Processed_Data/T2D_Data/2001_0_20201102_processed.csv
# (824, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed 2029_0_20210526.xlsx and saved to Processed_Data/T2D_Data/2029_0_20210526_processed.csv

# %% [markdown]
# # Participant's Data

# %%
output_folder = 'Processed_Data/T2D_Data'
filename = 'participant_data.csv'
output_file_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_processed.csv")

# Load the CSV file
try:
  df = pd.read_csv('participant_data.csv', skiprows=range(0, 1))
  df['Historic Glucose mmol/L'].replace('', pd.NA)
  df.dropna(subset=['Historic Glucose mmol/L'])

  # Extract time from the timestamp and rename columns
  df['Time'] = pd.to_datetime(df['Device Timestamp'], dayfirst=True).dt.time  # Extract time
  df['Glucose'] = df['Historic Glucose mmol/L']  # Rename column

  # Create extra time and classification attributes
  df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
  df['Hour'] = df['Time'].dt.hour
  df['Minute'] = df['Time'].dt.minute
  df["Hour_sin"] = np.sin(2 * np.pi * df["Hour"] / 24)
  df["Hour_cos"] = np.cos(2 * np.pi * df["Hour"] / 24)
  df["Minute_sin"] = np.sin(2 * np.pi * df["Minute"] / 60)
  df["Minute_cos"] = np.cos(2 * np.pi * df["Minute"] / 60)

  # Define glucose level thresholds
  bins = [-float('inf'), 2.5, 5, 8, 10, float('inf')]
  labels = ['Very Low', 'Low', 'Normal', 'High', 'Very High']
  df['Glucose_Level_Range'] = pd.cut(df['Glucose'], bins=bins, labels=labels)

  #Create attributes and values for future time-prediction modelling
  # Rolling window features
  df["Glucose_roll_mean"] = df["Glucose"].rolling(window=5, min_periods=1).mean()

  # Previous glucose values
  df["Glucose_lag1"] = df["Glucose"].shift(1)
  df["Glucose_lag2"] = df["Glucose"].shift(2)
  df["Glucose_lag3"] = df["Glucose"].shift(3)
  df["Glucose_lag4"] = df["Glucose"].shift(4)

  # Future glucose values
  df["Glucose_15min"] = df["Glucose"].shift(-1)  # 15 minutes ahead
  df["Glucose_30min"] = df["Glucose"].shift(-2)  # 30 minutes ahead
  df["Glucose_45min"] = df["Glucose"].shift(-3)  # 45 minutes ahead
  df["Glucose_60min"] = df["Glucose"].shift(-4) # 60 minutes ahead

  # Create a new DataFrame with only the desired columns
  new_df = df[['Time', 'Glucose', 'Hour', 'Minute', 'Glucose_Level_Range', 'Hour_sin', 'Hour_cos',
                         'Minute_sin', 'Minute_cos','Glucose_roll_mean','Glucose_lag1', 'Glucose_lag2', 'Glucose_lag3', 'Glucose_lag4',
                         'Glucose_15min', 'Glucose_30min', 'Glucose_45min', 'Glucose_60min']]

  # Get rid of null values
  new_df['Glucose'].replace('', pd.NA)
  new_df = new_df.dropna(subset=['Glucose'])

  # Write to a CSV file
  new_df.to_csv(output_file_path, index=False)
  created_df = pd.read_csv(output_file_path)

  #Drop null values
  created_df.dropna(inplace=True)
  created_df.to_csv(output_file_path, index=False)

  # Shape and missing values
  print(created_df.shape)
  print("Missing values:")
  print(created_df.isna().sum())

  print(f"\nProcessed {filename} and saved to {output_file_path}")
except Exception as e:
  print(f"Failed to process {filename}: {e}")
# Out:
# (21993, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Processed participant_data.csv and saved to Processed_Data/T2D_Data/participant_data_processed.csv

# %% [markdown]
# # Create Concatenated CSV Files

# %%
def concatenate_csv_files(input_folder, output_file):
  # Get a list of all CSV files in the folder
  csv_files = glob.glob(os.path.join(input_folder, "*.csv"))

  # Initialize an empty list to store DataFrames
  df_list = []

  # Loop through each file and append its contents to the list
  for file in csv_files:
    df = pd.read_csv(file)  # Read CSV file
    df_list.append(df)  # Append DataFrame to list

  # Concatenate all DataFrames into one
  final_df = pd.concat(df_list, ignore_index=True)

  # Get rid of null values
  final_df['Glucose'].replace('', pd.NA)
  final_df = final_df.dropna(subset=['Glucose'])

  # Save the combined DataFrame to a new CSV file
  final_df.to_csv(output_file, index=False)

  # Shape and missing values
  print(final_df.shape)
  print("Missing values:")
  print(final_df.isna().sum())

  print(f"\nSuccessfully merged {len(csv_files)} files into", output_file)

concatenate_csv_files('Processed_Data/T1D_Data', 'Processed_Data/T1D_Data/combined_T1D_data.csv')
concatenate_csv_files('Processed_Data/T2D_Data', 'Processed_Data/T2D_Data/combined_T2D_data.csv')
# Out:
# (89233, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Successfully merged 17 files into Processed_Data/T1D_Data/combined_T1D_data.csv
# (128597, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Successfully merged 106 files into Processed_Data/T2D_Data/combined_T2D_data.csv

# %% [markdown]
# ### Concatenate Ohio Files

# %%
# Define folder containing CSV files
folder_path = 'Processed_Data/T1D_Data'

# Get a list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Initialize an empty list to store DataFrames
df_list = []
count = 0

# Loop through each file and append its contents to the list
for file in csv_files:
  if '-ws-' in file:
    count += 1
    df = pd.read_csv(file)  # Read CSV file
    df_list.append(df)  # Append DataFrame to list

# Concatenate all DataFrames into one
final_df = pd.concat(df_list, ignore_index=True)

# Get rid of null values
final_df['Glucose'].replace('', pd.NA)
final_df = final_df.dropna(subset=['Glucose'])

# Save the combined DataFrame to a new CSV file
final_df.to_csv('Processed_Data/T1D_Data/combined_ohio_data.csv', index=False)

# Shape and missing values
print(final_df.shape)
print("Missing values:")
print(final_df.isna().sum())

print(f"\nSuccessfully merged {count} files into 'combined_ohio_data.csv'")
# Out:
# (85033, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_Level_Range    0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Successfully merged 12 files into 'combined_ohio_data.csv'

# %% [markdown]
# ### Concatenate ShanghaiT1D Files

# %%
# Define folder containing CSV files
folder_path = 'Processed_Data/T1D_Data'

# Get a list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Initialize an empty list to store DataFrames
df_list = []
count = 0

# Loop through each file and append its contents to the list
for file in csv_files:
  if '10' in file:
    count += 1
    df = pd.read_csv(file)  # Read CSV file
    df_list.append(df)  # Append DataFrame to list

# Concatenate all DataFrames into one
final_df = pd.concat(df_list, ignore_index=True)

# Get rid of null values
final_df['Glucose'].replace('', pd.NA)
final_df = final_df.dropna(subset=['Glucose'])

# Save the combined DataFrame to a new CSV file
final_df.to_csv('Processed_Data/T1D_Data/combined_shanghait1d_data.csv', index=False)

# Shape and missing values
print(final_df.shape)
print("Missing values:")
print(final_df.isna().sum())

print(f"\nSuccessfully merged {count} files into 'combined_shanghait1d_data.csv'")
# Out:
# (4200, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Successfully merged 5 files into 'combined_shanghait1d_data.csv'

# %% [markdown]
# ### Concatenate ShanghaiT2D Files

# %%
# Define folder containing CSV files
folder_path = 'Processed_Data/T2D_Data'

# Get a list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Initialize an empty list to store DataFrames
df_list = []
count = 0

# Loop through each file and append its contents to the list
for file in csv_files:
  if '20' in file:
    count += 1
    df = pd.read_csv(file)  # Read CSV file
    df_list.append(df)  # Append DataFrame to list

# Concatenate all DataFrames into one
final_df = pd.concat(df_list, ignore_index=True)

# Get rid of null values
final_df['Glucose'].replace('', pd.NA)
final_df = final_df.dropna(subset=['Glucose'])

# Save the combined DataFrame to a new CSV file
final_df.to_csv('Processed_Data/T2D_Data/combined_shanghait2d_data.csv', index=False)

# Shape and missing values
print(final_df.shape)
print("Missing values:")
print(final_df.isna().sum())

print(f"\nSuccessfully merged {count} files into 'combined_shanghait2d_data.csv'")
# Out:
# (106604, 18)
# Missing values:
# Time                   0
# Glucose                0
# Hour                   0
# Minute                 0
# Glucose_Level_Range    0
# Hour_sin               0
# Hour_cos               0
# Minute_sin             0
# Minute_cos             0
# Glucose_roll_mean      0
# Glucose_lag1           0
# Glucose_lag2           0
# Glucose_lag3           0
# Glucose_lag4           0
# Glucose_15min          0
# Glucose_30min          0
# Glucose_45min          0
# Glucose_60min          0
# dtype: int64
#
# Successfully merged 105 files into 'combined_shanghait2d_data.csv'
